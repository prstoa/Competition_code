# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 지역별 분류

# %%
foreigner=pd.read_csv('foreigner.csv')
foreigner=foreigner.iloc[:,1:]
# foreigner=foreigner[foreigner['GB3']!='의료']
foreigner['VLM/USEC']=foreigner['VLM']/foreigner['USEC']
foreigner=foreigner.drop('APV_TS_DL_TM_R', axis=1)
foreigner
# Out:
#               NT  V2    V3 GB3   GB2   TA_YM DAW_CCD_R       VLM  USEC  \
# 0             태국  서울   용산구  쇼핑  기타지출  201703     WHITE   3917910    55
# 1             일본  서울   용산구  쇼핑  기타지출  201805     WHITE  11586560   261
# 2             영국  서울   용산구  쇼핑  기타지출  201807     WHITE   3483630   120
# 3            베트남  경기   오산시  쇼핑  기타지출  201705     WHITE     12000     9
# 4             미국  서울   용산구  쇼핑  기타지출  201802       RED  20831646   449
# ...          ...  ..   ...  ..   ...     ...       ...       ...   ...
# 2730134  오스트레일리아  부산   사상구  쇼핑  기타쇼핑  202006       RED     15000     1
# 2730135       미국  대전    동구  음식    유흥  202005       RED    160000     1
# 2730136       중국  부산  부산진구  음식    유흥  202006     WHITE    202171     2
# 2730137       일본  경기   파주시  의료  치과병원  202001     WHITE     11900     1
# 2730138  오스트레일리아  부산   동래구  숙박  그외숙박  202004     WHITE     50000     1
#
#               VLM/USEC
# 0         71234.727273
# 1         44392.950192
# 2         29030.250000
# ...

# %%
foreigner['GB3'].unique()
# Out:
# array(['쇼핑', '스포츠', '체험', '교통', '의료', '음식', '숙박'], dtype=object)

# %%
import matplotlib.font_manager as fm
plt.rcParams['axes.unicode_minus'] = False
path = 'NanumBarunGothic.ttf'
font_name = fm.FontProperties(fname=path, size=12)

# %%
foreigner[foreigner['V2']=='경기']['V2']
# Out:
# 3          경기
# 5          경기
# 6          경기
# 11         경기
# 22         경기
#            ..
# 2730124    경기
# 2730129    경기
# 2730130    경기
# 2730133    경기
# 2730137    경기
# Name: V2, Length: 495593, dtype: object

# %%
foreigner[foreigner['V2']=='경기']['V3']
# Out:
# 3          오산시
# 5          오산시
# 6          오산시
# 11         평택시
# 22         평택시
#           ...
# 2730124    고양시
# 2730129    성남시
# 2730130    평택시
# 2730133    화성시
# 2730137    파주시
# Name: V3, Length: 495593, dtype: object

# %%
foreigner[foreigner['V2']=='경기'].index
# Out:
# Int64Index([      3,       5,       6,      11,      22,      24,      36,
#                  46,      51,      53,
#             ...
#             2730087, 2730094, 2730098, 2730116, 2730118, 2730124, 2730129,
#             2730130, 2730133, 2730137],
#            dtype='int64', length=495593)

# %%
''.join(list(foreigner.iloc[3]['V3']))
# Out:
# '오산시'

# %%
foreigner
# Out:
#               NT  V2    V3 GB3   GB2   TA_YM DAW_CCD_R       VLM  USEC  \
# 0             태국  서울   용산구  쇼핑  기타지출  201703     WHITE   3917910    55
# 1             일본  서울   용산구  쇼핑  기타지출  201805     WHITE  11586560   261
# 2             영국  서울   용산구  쇼핑  기타지출  201807     WHITE   3483630   120
# 3            베트남  경기   오산시  쇼핑  기타지출  201705     WHITE     12000     9
# 4             미국  서울   용산구  쇼핑  기타지출  201802       RED  20831646   449
# ...          ...  ..   ...  ..   ...     ...       ...       ...   ...
# 2730134  오스트레일리아  부산   사상구  쇼핑  기타쇼핑  202006       RED     15000     1
# 2730135       미국  대전    동구  음식    유흥  202005       RED    160000     1
# 2730136       중국  부산  부산진구  음식    유흥  202006     WHITE    202171     2
# 2730137       일본  경기   파주시  의료  치과병원  202001     WHITE     11900     1
# 2730138  오스트레일리아  부산   동래구  숙박  그외숙박  202004     WHITE     50000     1
#
#               VLM/USEC
# 0         71234.727273
# 1         44392.950192
# 2         29030.250000
# ...

# %%
foreigner[foreigner['V2']=='경기']['']
# Out:
#             NT  V2   V3 GB3      GB2   TA_YM DAW_CCD_R       VLM  USEC  \
# 3          베트남  경기  오산시  쇼핑     기타지출  201705     WHITE     12000     9
# 5           일본  경기  오산시  쇼핑     기타지출  201807     WHITE      7000     3
# 6           미국  경기  오산시  쇼핑     기타지출  201801     WHITE    700600    79
# 11          미국  경기  평택시  쇼핑     기타지출  201712       RED  19879440   472
# 22          미국  경기  평택시  쇼핑     기타지출  201711       RED  11609560   342
# ...        ...  ..  ...  ..      ...     ...       ...       ...   ...
# 2730124    싱가폴  경기  고양시  의료  한의원,한약방  202002     WHITE     40880     1
# 2730129     독일  경기  성남시  의료     치과병원  202001     WHITE     17000     1
# 2730130  말레이지아  경기  평택시  숙박     그외숙박  202001       RED    100980     1
# 2730133    캐나다  경기  화성시  의료     치과병원  202006     WHITE     15700     1
# 2730137     일본  경기  파주시  의료     치과병원  202001     WHITE     11900     1
#
#               VLM/USEC
# 3          1333.333333
# 5          2333.333333
# 6          8868.354430
# ...

# %%
for i in foreigner[foreigner['V2']=='경기'].index :
    foreigner.iloc[i]['V2']=foreigner.iloc[i]['V3']
# Out:
# <ipython-input-52-5c2893f53bca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   foreigner.iloc[i]['V2']=foreigner.iloc[i]['V3']

# %%
plt.figure(figsize=(20,12))
plt.xticks(fontproperties =font_name)
sns.lineplot(foreigner['V2'],foreigner['USEC'])
# Out:
# <AxesSubplot:xlabel='V2', ylabel='USEC'>
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# * 평택, 동두천

# %%
plt.figure(figsize=(20,12))
sns.lineplot(foreigner[foreigner['V2']=='경기']['V3'],foreigner[foreigner['V2']=='경기']['USEC'])
# Out:
# <AxesSubplot:xlabel='V3', ylabel='USEC'>
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44400 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda\envs\college\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anacon