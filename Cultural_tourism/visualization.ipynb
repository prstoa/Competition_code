# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # native

# %% [markdown]
# -

# %%
native_travel=pd.read_csv('native_travel.csv')
native_culture=pd.read_csv('native_culture.csv')
native_sport=pd.read_csv('native_sport.csv')

# %%
native_culture
# Out:
#          v1  v2    v3     gb3   gb2 sex_ccd  cln_age_r   ta_ym daw_ccd_r  \
# 0        전남  광주    동구  문화예술활동  사진촬영       M         20  201701     WHITE
# 1        광주  광주    북구  문화예술활동  공연관람       M         40  201701       RED
# 2        부산  부산    북구  문화예술활동  공연관람       M         20  201701     WHITE
# 3        광주  광주    북구  문화예술활동  사진촬영       M         50  201701       RED
# 4        대구  대구    북구  문화예술활동  공연관람       F         40  201701     WHITE
# ...      ..  ..   ...     ...   ...     ...        ...     ...       ...
# 2837185  광주  서울  영등포구  문화예술활동  공연관람       M         60  202006       RED
# 2837186  경북  서울  영등포구  문화예술활동  공연관람       M         50  202006     WHITE
# 2837187  울산  경기  의정부시  문화예술활동  공연관람       M         20  202006       RED
# 2837188  충남  부산  해운대구  문화예술활동  공연관람       M         20  202006       RED
# 2837189  경남  부산  해운대구  문화예술활동  공연관람       M         20  202006       RED
#
#         apv_ts_dl_tm_r         vlm  usec       vlm/usec
# ...

# %%
native_culture['gb2'].value_counts()*usec
# Out:
# 공연관람      1526136
# 사진촬영       601214
# 미술공예참여     398813
# 음악감상       191329
# 악기연주       119698
# Name: gb2, dtype: int64

# %%
native_travel
# Out:
#          v1  v2    v3 gb3   gb2 sex_ccd  cln_age_r   ta_ym daw_ccd_r  \
# 0        울산  울산    남구  여행    숙박       M         20  201701       RED
# 1        충북  대전    동구  여행    교통       F         20  201701     WHITE
# 2        경북  대전    동구  여행    교통       M         30  201701       RED
# 3        경북  대전    동구  여행    교통       F         30  201701     WHITE
# 4        광주  대전    동구  여행    교통       F         20  201701     WHITE
# ...      ..  ..   ...  ..   ...     ...        ...     ...       ...
# 5726154  인천  서울  영등포구  여행    체험       M         40  202006     WHITE
# 5726155  충남  경기  의정부시  여행    숙박       M         40  202006     WHITE
# 5726156  경기  경기  의정부시  여행    숙박       F         60  202006       RED
# 5726157  부산  부산  해운대구  여행  관광쇼핑       M         50  202006     WHITE
# 5726158  부산  부산  해운대구  여행  관광쇼핑       M         30  202006       RED
#
#         apv_ts_dl_tm_r          vlm   usec       vlm/usec
# 0                   활동   29642635.0    895   33120.262570
# ...

# %%
native_culture['gb2'].value_counts()
# Out:
# 공연관람      1526136
# 사진촬영       601214
# 미술공예참여     398813
# 음악감상       191329
# 악기연주       119698
# Name: gb2, dtype: int64

# %%
native=pd.concat([native_travel,native_culture,native_sport],sort=False, ignore_index=True)
native['ta_ym']=pd.to_datetime(native['ta_ym'],format='%Y%m')
native
# Out:
#          v1  v2   v3    gb3     gb2 sex_ccd  cln_age_r      ta_ym daw_ccd_r  \
# 0        울산  울산   남구     여행      숙박       M         20 2017-01-01       RED
# 1        충북  대전   동구     여행      교통       F         20 2017-01-01     WHITE
# 2        경북  대전   동구     여행      교통       M         30 2017-01-01       RED
# 3        경북  대전   동구     여행      교통       F         30 2017-01-01     WHITE
# 4        광주  대전   동구     여행      교통       F         20 2017-01-01     WHITE
# ...      ..  ..  ...    ...     ...     ...        ...        ...       ...
# 8566502  경남  경남  창원시  스포츠활동  운동경기관람       F         30 2020-06-01     WHITE
# 8566503  경기  대구  수성구  스포츠활동  운동경기관람       M         30 2020-06-01     WHITE
# 8566504  경북  대구  수성구  스포츠활동  운동경기관람       F         40 2020-06-01       RED
# 8566505  경기  경기  파주시  스포츠활동  운동경기관람       M         30 2020-06-01       RED
# 8566506  경기  경기  파주시  스포츠활동  운동경기관람       M         40 2020-06-01       RED
#
#         apv_ts_dl_tm_r          vlm   usec      vlm/usec
# ...

# %%
n_index=native[native['v2']=='경기'].index

# %%
native.iloc[n_index,2]='경기'

# %%
native.iloc[n_index,2]
# Out:
# 88         경기
# 89         경기
# 93         경기
# 138        경기
# 167        경기
#            ..
# 8566496    경기
# 8566497    경기
# 8566500    경기
# 8566505    경기
# 8566506    경기
# Name: v3, Length: 1255784, dtype: object

# %%
native
# Out:
#          v1  v2   v3    gb3     gb2 sex_ccd  cln_age_r      ta_ym daw_ccd_r  \
# 0        울산  울산   남구     여행      숙박       M         20 2017-01-01       RED
# 1        충북  대전   동구     여행      교통       F         20 2017-01-01     WHITE
# 2        경북  대전   동구     여행      교통       M         30 2017-01-01       RED
# 3        경북  대전   동구     여행      교통       F         30 2017-01-01     WHITE
# 4        광주  대전   동구     여행      교통       F         20 2017-01-01     WHITE
# ...      ..  ..  ...    ...     ...     ...        ...        ...       ...
# 8566502  경남  경남  창원시  스포츠활동  운동경기관람       F         30 2020-06-01     WHITE
# 8566503  경기  대구  수성구  스포츠활동  운동경기관람       M         30 2020-06-01     WHITE
# 8566504  경북  대구  수성구  스포츠활동  운동경기관람       F         40 2020-06-01       RED
# 8566505  경기  경기   경기  스포츠활동  운동경기관람       M         30 2020-06-01       RED
# 8566506  경기  경기   경기  스포츠활동  운동경기관람       M         40 2020-06-01       RED
#
#         apv_ts_dl_tm_r          vlm   usec      vlm/usec
# ...

# %%
for i in native[native['v2']=='경기'].index:
    native['v2'].iloc[i]=native['v3'].iloc[i]

# %%
native.apply(lambda x : native['v3'] if x=='경기' else x, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-84b73ef95fb0> in <module>
# ----> 1 native.apply(lambda x : native['v3'] if x=='경기' else x, axis=1)
#
# C:\anaconda\envs\college\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7539             kwds=kwds,
#    7540         )
# -> 7541         return op.get_result()
#    7542
#    7543     def applymap(self, func) -> "DataFrame":
#
# C:\anaconda\envs\college\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# C:\anaconda\envs\college\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# ...

# %%
r_native=native.groupby('v2')['v3','usec'].sum().reset_index()
r_native['v2']=le.fit_transform(r_native['v2'])
plt.figure(figsize=(20,12))
sns.lineplot(r_native['v2'],r_native['usec'])

# %%
r_native=native.groupby('v2')['v3','usec'].sum().reset_index()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
r_native['v2']=le.fit_transform(r_native['v2'])
print(le.classes_)
plt.figure(figsize=(20,12))
sns.lineplot(r_native['v2'],r_native['usec'])
# Out:
# <ipython-input-67-05be2fc20a4c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   r_native=native.groupby('v2')['v3','usec'].sum().reset_index()
# ['강원' '경기' '경남' '경북' '광주' '대구' '대전' '부산' '서울' '세종' '울산' '인천' '전남' '전북'
#  '제주' '충남' '충북']
# <AxesSubplot:xlabel='v2', ylabel='usec'>

# %%
r_native_travel=native_travel.groupby('v2')['v3','usec'].sum().reset_index()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
r_native_travel['v2']=le.fit_transform(r_native_travel['v2'])
print(le.classes_)
plt.figure(figsize=(20,12))
sns.lineplot(r_native_travel['v2'],r_native_travel['usec'])
# Out:
# <ipython-input-69-3d20d9468013>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   r_native_travel=native_travel.groupby('v2')['v3','usec'].sum().reset_index()
# ['강원' '경기' '경남' '경북' '광주' '대구' '대전' '부산' '서울' '세종' '울산' '인천' '전남' '전북'
#  '제주' '충남' '충북']
# <AxesSubplot:xlabel='v2', ylabel='usec'>

# %%
r_native_culture=native_culture.groupby('v2')['v3','usec'].sum().reset_index()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
r_native_culture['v2']=le.fit_transform(r_native_culture['v2'])
print(le.classes_)
plt.figure(figsize=(20,12))
sns.lineplot(r_native_culture['v2'],r_native_culture['usec'])
# Out:
# ['강원' '경기' '경남' '경북' '광주' '대구' '대전' '부산' '서울' '세종' '울산' '인천' '전남' '전북'
#  '제주' '충남' '충북']
# <ipython-input-68-614e9a1b7acd>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   r_native_culture=native_culture.groupby('v2')['v3','usec'].sum().reset_index()
# <AxesSubplot:xlabel='v2', ylabel='usec'>

# %%
r_native_sport=native_sport.groupby('v2')['v3','usec'].sum().reset_index()
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
r_native_sport['v2']=le.fit_transform(r_native_sport['v2'])
print(le.classes_)
plt.figure(figsize=(20,12))
sns.lineplot(r_native_sport['v2'],r_native_sport['usec'])
# Out:
# ['강원' '경기' '경남' '경북' '대구' '대전' '서울' '인천' '전남' '전북' '충남']
# <ipython-input-70-af36000db972>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   r_native_sport=native_sport.groupby('v2')['v3','usec'].sum().reset_index()
# <AxesSubplot:xlabel='v2', ylabel='usec'>
